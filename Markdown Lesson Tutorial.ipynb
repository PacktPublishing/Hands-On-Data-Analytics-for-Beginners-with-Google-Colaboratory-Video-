# %% [markdown]
# # Headers and Emphasis

# %% [markdown]
# ## A Smaller Header Example

# %% [markdown]
# ## Emphasis

# %% [markdown]
# This is an example of how to __italicize__ our example.

# %% [markdown]
# ## Line Breaks

# %% [markdown]
# A New Section
#
# ---

# %% [markdown]
# # Lists

# %% [markdown]
# 1. Sections 1
# 2. Sections 2
# 3. Sections 3

# %% [markdown]
# # Tables

# %% [markdown]
# | height | age | weight |
# | ------- | ------- | ------- |
# | 5'6 | 12 | 130 |
# | 5'3 | 19 | 100 |
# | 6'1 | 24 | 230 |

# %% [markdown]
# # Highlighted Code

# %% [markdown]
# ```
# for i in range(0, len(list)):
#   count += 1
# ```

# %% [markdown]
# # Links

# %% [markdown]
# [Google](https://www.google.com)
