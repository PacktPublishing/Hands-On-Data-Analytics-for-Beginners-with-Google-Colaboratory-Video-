# %% [markdown]
# # Jupyter Notebook and Colab Tutorial
#
# ---

# %% [markdown]
# Hello world.

# %% [markdown]
# Another text message.

# %%
print("This is my first python code in jupyter notebooks!")

# %%
print("hello world!")

# %% [markdown]
# # My first header

# %% [markdown]
# # Markdown Tutorial
#
# ---

# %% [markdown]
# # Headers and Emphasis

# %% [markdown]
# ## A Smaller Header Example

# %% [markdown]
# ## Emphasis

# %% [markdown]
# This is an example of how to __italicize__ our example.

# %% [markdown]
# ## Line Breaks

# %% [markdown]
# A New Section
#
# ---

# %% [markdown]
# # Lists

# %% [markdown]
# 1. Sections 1
# 2. Sections 2
# 3. Sections 3

# %% [markdown]
# # Tables

# %% [markdown]
# | height | age | weight |
# | ------- | ------- | ------- |
# | 5'6 | 12 | 130 |
# | 5'3 | 19 | 100 |
# | 6'1 | 24 | 230 |

# %% [markdown]
# # Highlighted Code

# %% [markdown]
# ```
# for i in range(0, len(list)):
#   count += 1
# ```

# %% [markdown]
# # Links

# %% [markdown]
# [Google](https://www.google.com)

# %% [markdown]
# # LaTeX Tutorial
#
# ---

# %% [markdown]
# # Relations

# %% [markdown]
# $y = f(x)$
#
# $y \neq f(x)$
#
# $2 < x > 1$
#
# $0 \leq x \geq 1$
#
# \$
#
# "The current stock price is worth \$20, but just the other day it was \$16."

# %% [markdown]
# # Operators

# %% [markdown]
# $x + y$
#
# $x - y$
#
# $x * y$
#
# $x / y$
#
# $2 \times 3$
#
# $4 \div 2$

# %% [markdown]
# # Fractions and Groupings

# %% [markdown]
# $^1/_2$
#
# $2 \over 3$
#
# $\frac{1}{2}$
#
# $\frac{3x}{5yz}$

# %% [markdown]
# # Powers

# %% [markdown]
# $x^2$
#
# $3^n$
#
# $\frac{3x}{5y^2z}$
#
# $\frac{3x}{5y^{2z}}$

# %% [markdown]
# # Roots

# %% [markdown]
# $\sqrt4$
#
# $\sqrt{3-1}$
#
# $\sqrt[3]{8}$

# %% [markdown]
# # Logs

# %% [markdown]
# $\log_x x = 1$
#
# $\log_2 16 = 4$

# %% [markdown]
# # Indices

# %% [markdown]
# $x_1$
#
# $x_2$
#
# $x_{n1}$
#
# $x_{i_j}$
#
# $f(x) = ax_3^n + bx_2^{n-1} + cx_1^{n-2}$

# %% [markdown]
# # Sums

# %% [markdown]
# $\sum$
#
# $\sum\limits_{a}^{b}x$
#
# $\sum\limits_{a}^{b}x^2$
#
# $\sum\limits_{x=0}^{x=5}x+2$

# %% [markdown]
# # Limits

# %% [markdown]
# $\lim\limits_{x \to 0}$
#
# $\lim\limits_{x \to \infty}$
#
# $\lim\limits_{x \to 0^+} {1 \over 0} = \infty$

# %% [markdown]
# # Integrals

# %% [markdown]
# $\int$
#
# $\int\limits_{a}^{b} x$
#
# $\int\limits_{0}^{1} x^2dx$
#
# $\int\limits_{-2n}^{2n} f(x)dx = \int\limits_{-2n}^{2n^{4e}}dx$
